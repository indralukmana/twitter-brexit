# %%
# %%bash
#
# head "2016-06-23:03:34:01.json"

# %%
import json
import pandas as pd
from pandas.io.json import json_normalize

twitter_filename = "2016-06-23:02:34:01.json"
twitter_file = open(twitter_filename, 'r')

tweets = []

count = 0
df_tweets = pd.DataFrame()

with twitter_file as f:
    for line in f:
#         tweet = json.loads(line)
#         df_tweets.append(json_normalize(tweet))

        
        if count == 10:
            break
        else:
            tweet = json.loads(line)
            df_tweets = df_tweets.append(json_normalize(tweet))
            count = count + 1

# %%
df_tweets
# Out:
#   contributors coordinates                      created_at  \
# 0         None        None  Thu Jun 23 01:34:05 +0000 2016
# 0         None        None  Thu Jun 23 01:34:05 +0000 2016
# 0         None        None  Thu Jun 23 01:34:05 +0000 2016
# 0         None        None  Thu Jun 23 01:34:06 +0000 2016
# 0         None        None  Thu Jun 23 01:34:06 +0000 2016
# 0         None        None  Thu Jun 23 01:34:07 +0000 2016
# 0         None        None  Thu Jun 23 01:34:07 +0000 2016
# 0         None        None  Thu Jun 23 01:34:07 +0000 2016
# 0         None        None  Thu Jun 23 01:34:08 +0000 2016
# 0         None        None  Thu Jun 23 01:34:08 +0000 2016
#
#                                    entities.hashtags  \
# 0  [{'text': 'EU', 'indices': [48, 51]}, {'text':...
# 0      [{'text': 'VoteRemain', 'indices': [34, 45]}]
# 0         [{'text': 'EUref', 'indices': [119, 125]}]
# 0  [{'text': 'Brexit', 'indices': [84, 91]}, {'te...
# ...

# %%
list(df_tweets)
# Out:
# ['contributors',
#  'coordinates',
#  'created_at',
#  'entities.hashtags',
#  'entities.media',
#  'entities.symbols',
#  'entities.urls',
#  'entities.user_mentions',
#  'extended_entities.media',
#  'favorite_count',
#  'favorited',
#  'filter_level',
#  'geo',
#  'id',
#  'id_str',
#  'in_reply_to_screen_name',
#  'in_reply_to_status_id',
#  'in_reply_to_status_id_str',
#  'in_reply_to_user_id',
#  'in_reply_to_user_id_str',
#  'is_quote_status',
#  'lang',
#  'place',
#  'possibly_sensitive',
#  'quoted_status.contributors',
#  'quoted_status.coordinates',
#  'quoted_status.created_at',
#  'quoted_status.entities.hashtags',
#  'quoted_status.entities.media',
#  'quoted_status.entities.symbols',
#  'quoted_status.entities.urls',
#  'quoted_status.entities.user_mentions',
#  'quoted_status.extended_entities.media',
#  'quoted_status.favorite_count',
#  'quoted_status.favorited',
#  'quoted_status.filter_level',
#  'quoted_status.geo',
#  'quoted_status.id',
# ...

# %%
df_tweets.head()
# Out:
#   contributors coordinates                      created_at  \
# 0         None        None  Thu Jun 23 01:34:05 +0000 2016
# 0         None        None  Thu Jun 23 01:34:05 +0000 2016
# 0         None        None  Thu Jun 23 01:34:05 +0000 2016
# 0         None        None  Thu Jun 23 01:34:06 +0000 2016
# 0         None        None  Thu Jun 23 01:34:06 +0000 2016
#
#                                    entities.hashtags  \
# 0  [{'text': 'EU', 'indices': [48, 51]}, {'text':...
# 0      [{'text': 'VoteRemain', 'indices': [34, 45]}]
# 0         [{'text': 'EUref', 'indices': [119, 125]}]
# 0  [{'text': 'Brexit', 'indices': [84, 91]}, {'te...
# 0  [{'text': 'VoteLeave', 'indices': [83, 93]}, {...
#
#                                       entities.media entities.symbols  \
# 0  [{'sizes': {'small': {'w': 595, 'resize': 'fit...               []
# 0                                                NaN               []
# 0                                                NaN               []
# ...

# %%
df_tweets[df_tweets['entities.media'].isnull() == False]
# Out:
#   contributors coordinates                      created_at  \
# 0         None        None  Thu Jun 23 01:34:05 +0000 2016
# 0         None        None  Thu Jun 23 01:34:07 +0000 2016
# 0         None        None  Thu Jun 23 01:34:07 +0000 2016
#
#                                    entities.hashtags  \
# 0  [{'text': 'EU', 'indices': [48, 51]}, {'text':...
# 0           [{'text': 'EUref', 'indices': [72, 78]}]
# 0  [{'text': 'Brexit', 'indices': [0, 7]}, {'text...
#
#                                       entities.media entities.symbols  \
# 0  [{'sizes': {'small': {'w': 595, 'resize': 'fit...               []
# 0  [{'sizes': {'thumb': {'w': 150, 'resize': 'cro...               []
# 0  [{'sizes': {'thumb': {'w': 150, 'resize': 'cro...               []
#
#                                        entities.urls  \
# 0                                                 []
# 0                                                 []
# 0  [{'expanded_url': 'https://www.theguardian.com...
#
# ...
