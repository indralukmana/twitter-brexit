# %%
import json
import pandas as pd
from pandas.io.json import json_normalize

twitter_path = "input/2017-09-23/"
twitter_filename = "2017-09-23:03:05:01.json"
twitter_file = open(twitter_path+twitter_filename, 'r')
tweets = []

count = 0
df_tweets = pd.DataFrame()

with twitter_file as f:
    for line in f:
#         if count == 1000:
#             break
#         else:
        tweet = json.loads(line)
        df_tweets = df_tweets.append(json_normalize(tweet))
        count = count + 1

# %%
list(df_tweets)
# Out:
# ['contributors',
#  'coordinates',
#  'coordinates.coordinates',
#  'coordinates.type',
#  'created_at',
#  'display_text_range',
#  'entities.hashtags',
#  'entities.media',
#  'entities.symbols',
#  'entities.urls',
#  'entities.user_mentions',
#  'extended_entities.media',
#  'extended_tweet.display_text_range',
#  'extended_tweet.entities.hashtags',
#  'extended_tweet.entities.media',
#  'extended_tweet.entities.symbols',
#  'extended_tweet.entities.urls',
#  'extended_tweet.entities.user_mentions',
#  'extended_tweet.extended_entities.media',
#  'extended_tweet.full_text',
#  'favorite_count',
#  'favorited',
#  'filter_level',
#  'geo',
#  'geo.coordinates',
#  'geo.type',
#  'id',
#  'id_str',
#  'in_reply_to_screen_name',
#  'in_reply_to_status_id',
#  'in_reply_to_status_id_str',
#  'in_reply_to_user_id',
#  'in_reply_to_user_id_str',
#  'is_quote_status',
#  'lang',
#  'place',
#  'place.bounding_box.coordinates',
#  'place.bounding_box.type',
#  'place.country',
# ...

# %%
df_tweets.head()
# Out:
#   contributors coordinates coordinates.coordinates coordinates.type  \
# 0         None        None                     NaN              NaN
# 0         None        None                     NaN              NaN
# 0         None        None                     NaN              NaN
# 0         None        None                     NaN              NaN
# 0         None        None                     NaN              NaN
#
#                        created_at display_text_range  \
# 0  Sat Sep 23 02:05:20 +0000 2017            [0, 26]
# 0  Sat Sep 23 02:05:22 +0000 2017           [0, 107]
# 0  Sat Sep 23 02:05:26 +0000 2017                NaN
# 0  Sat Sep 23 02:05:26 +0000 2017                NaN
# 0  Sat Sep 23 02:05:27 +0000 2017                NaN
#
#                                    entities.hashtags  \
# 0            [{'indices': [0, 7], 'text': 'Brexit'}]
# 0  [{'indices': [36, 39], 'text': 'EU'}, {'indice...
# 0              [{'indices': [16, 19], 'text': 'EU'}]
# ...

# %%
df_tweets[df_tweets['retweet_count'] > 0]
# Out:
# Empty DataFrame
# ...

# %%
df_tweets['text'].head
# Out:
# <bound method NDFrame.head of 0    #Brexit going well, no?? 🙄 https://t.co/eLNXqv...
# 0    Click HERE▶️https://t.co/c0xqyAnNn7\n#EU #News...
# 0    RT @5050oD: The #EU has announced a €500 milli...
# 0    RT @HandofGOD7: ...says the wanker who's a lif...
# 0    RT @h0t_p0ppy: They dont suffer, they say\nOve...
# 0    RT @h0t_p0ppy: Are we humane? \nWe are human.....
# 0    RT @brexit_politics: Britain's credit rating d...
# 0    ⚡ Retweet &amp; Follow ⚡ \n\n  ⏩ @_o_GAZ_o_ \n...
# 0    RT @CGTNOfficial: Live: #UK Prime Minister The...
# 0    RT @YORBusinessExpo: ROI from social media? Cl...
# 0    RT @KTHopkins: Hey McCain. Meet May. You two s...
# 0    RT @Earindill: @hjoneshojo @SebDance @MsMainst...
# 0    RT @2010LeeHurst: This will be my final commen...
# 0    Know Truth More https://t.co/nZZCl7tnWG #EU #A...
# 0    RT @BCollier2012: Mrs May has delayed #Brexit ...
# 0    RT @SteveUnwin01: We will only #LeaveEU if @Co...
# 0    RT @MrIanHitchings: The UK didn't vote for a t...
# ...
