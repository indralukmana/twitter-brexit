# %% [markdown]
# # Twitter Brexit Analysis

# %% [markdown]
# ## Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import json
from pandas.io.json import json_normalize

# %% [markdown]
# ## Reading File

# %% [markdown]
# The data used in this project are tweets exported from Twitter in context of UK brexit.
#
# The generated data are stored as JSON files. In total they are approximately 18GB of compressed Tar files.
#
# The dataset is collected on 5 days around brexit.
#
# * 21 June 2016
# * 22 June 2016
# * 23 June 2016
# * 22 September 2017
# * 23 September 2017
#
# For each day there are JSON files for tweets about brexit collected every hour in 24 hours.
#
# Each JSON files varies with one another in size, ranging from 4MB in to 500MB.
#
# One of the question for this data is how do we analyze the most used hashtags in this topics of Brexit. As how they
#
# This project will try to analyze the tweets based on the top retweeted tweets and their hashtags.
#
# I use the bigest JSON file to analyze with around 34MB file size. In the JSON file the tweets are stored line by line. Each line represent a fully formatted JSON file representing tweet informations.

# %%
twitter_filename = "2017-09-23:11:05:01.json"
twitter_file = open(twitter_filename, 'r')

# %% [markdown]
# ## JSON to DataFrame

# %%
with twitter_file as f:
    first_line = f.readline()
    print (first_line)
    second_line = f.readline()
    print(second_line)
# Out:
# {"in_reply_to_status_id_str":null,"in_reply_to_status_id":null,"created_at":"Sat Sep 23 10:05:04 +0000 2017","in_reply_to_user_id_str":null,"source":"<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client<\/a>","retweeted_status":{"in_reply_to_status_id_str":null,"in_reply_to_status_id":null,"created_at":"Sat Sep 23 09:59:13 +0000 2017","in_reply_to_user_id_str":null,"source":"<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone<\/a>","retweet_count":2,"retweeted":false,"geo":null,"filter_level":"low","in_reply_to_screen_name":null,"is_quote_status":false,"id_str":"911530384046870528","in_reply_to_user_id":null,"favorite_count":0,"id":911530384046870528,"text":"#Brexit will turn EU from equal partner to competitor with better trade deals worldwide &amp; a more attractive market 500 vs 65 Mln! #ScotRef","place":null,"lang":"en","quote_count":0,"favorited":false,"coordinates":null,"truncated":false,"reply_count":0,"entities":{"urls":[],"hashtags":[{"indices":[0,7],"text":"Brexit"},{"indices":[134,142],"text":"ScotRef"}],"user_mentions":[],"symbols":[]},"contributors":null,"user":{"utc_offset":null,"friends_count":431,"profile_image_url_https":"https://pbs.twimg.com/profile_images/593006236414701568/oOtWP0RA_normal.png","listed_count":8,"profile_background_image_url":"http://abs.twimg.com/images/themes/theme1/bg.png","default_profile_image":false,"favourites_count":16108,"description":"Love my family, guitars and Scotland. We must control the present and take the opportunity to commit though crimes.","created_at":"Tue Apr 28 10:53:41 +0000 2015","is_translator":false,"profile_background_image_url_https":"https://abs.twimg.com/images/themes/theme1/bg.png","protected":false,"screen_name":"BigMarkyB","id_str":"3216761128","profile_link_color":"3B94D9","translator_type":"none","id":3216761128,"geo_enabled":true,"profile_background_color":"000000","lang":"en","profile_sidebar_border_color":"000000","profile_text_color":"000000","verified":false,"profile_image_url":"http://pbs.twimg.com/profile_images/593006236414701568/oOtWP0RA_normal.png","time_zone":null,"url":"http://noisesfaetheheid.wordpress.com","contributors_enabled":false,"profile_background_tile":false,"profile_banner_url":"https://pbs.twimg.com/profile_banners/3216761128/1430239188","statuses_count":8808,"follow_request_sent":null,"followers_count":513,"profile_use_background_image":false,"default_profile":false,"following":null,"name":"Mark Breingan","location":"Cumbernauld, Scotland","profile_sidebar_fill_color":"000000","notifications":null}},"retweet_count":0,"retweeted":false,"geo":null,"filter_level":"low","in_reply_to_screen_name":null,"is_quote_status":false,"id_str":"911531854305652738","in_reply_to_user_id":null,"favorite_count":0,"id":911531854305652738,"text":"RT @BigMarkyB: #Brexit will turn EU from equal partner to competitor with better trade deals worldwide &amp; a more attractive market 500 vs 65\u2026","place":null,"lang":"en","quote_count":0,"favorited":false,"coordinates":null,"truncated":false,"timestamp_ms":"1506161104166","reply_count":0,"entities":{"urls":[],"hashtags":[{"indices":[15,22],"text":"Brexit"}],"user_mentions":[{"indices":[3,13],"screen_name":"BigMarkyB","id_str":"3216761128","name":"Mark Breingan","id":3216761128}],"symbols":[]},"contributors":null,"user":{"utc_offset":0,"friends_count":174,"profile_image_url_https":"https://pbs.twimg.com/profile_images/883058397511376896/iPCB67WM_normal.jpg","listed_count":0,"profile_background_image_url":"","default_profile_image":false,"favourites_count":924,"description":"Hi, Robby really likes #scotref","created_at":"Fri Jun 30 19:43:33 +0000 2017","is_translator":false,"profile_background_image_url_https":"","protected":false,"screen_name":"fhathast_tha","id_str":"880874466393411585","profile_link_color":"1DA1F2","translator_type":"none","id":880874466393411585,"geo_enabled":false,"profile_background_color":"F5F8FA","lang":"en-gb","profile_sidebar_border_col ...
#
# {"in_reply_to_status_id_str":null,"in_reply_to_status_id":null,"created_at":"Sat Sep 23 10:05:04 +0000 2017","in_reply_to_user_id_str":null,"source":"<a href=\"http://twitter.com/#!/download/ipad\" rel=\"nofollow\">Twitter for iPad<\/a>","retweeted_status":{"in_reply_to_status_id_str":null,"in_reply_to_status_id":null,"created_at":"Fri Sep 22 15:04:21 +0000 2017","in_reply_to_user_id_str":null,"source":"<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client<\/a>","retweet_count":372,"retweeted":false,"geo":null,"filter_level":"low","in_reply_to_screen_name":null,"is_quote_status":false,"id_str":"911244784026521600","in_reply_to_user_id":null,"favorite_count":639,"id":911244784026521600,"text":"This will be my final comment on #Brexit as it is now confirmed it is not happening. Now we wait for our imposed migrant quota from Merkel.","place":null,"lang":"en","quote_count":16,"favorited":false,"coordinates":null,"truncated":false,"reply_count":71,"entities":{"urls":[],"hashtags":[{"indices":[33,40],"text":"Brexit"}],"user_mentions":[],"symbols":[]},"contributors":null,"user":{"utc_offset":3600,"friends_count":67,"profile_image_url_https":"https://pbs.twimg.com/profile_images/741256000263577600/ECP0i84l_normal.jpg","listed_count":227,"profile_background_image_url":"http://pbs.twimg.com/profile_background_images/633901571/pgo64gmtynqp73dwiq9q.jpeg","default_profile_image":false,"favourites_count":0,"description":"When I mute you I don't read your crap anymore. \nI use Leftist as a derogatory term to differentiate between twunts and decent left wing people.","created_at":"Fri May 07 16:37:23 +0000 2010","is_translator":false,"profile_background_image_url_https":"https://pbs.twimg.com/profile_background_images/633901571/pgo64gmtynqp73dwiq9q.jpeg","protected":false,"screen_name":"2010LeeHurst","id_str":"141269460","profile_link_color":"0099CC","translator_type":"none","id":141269460,"geo_enabled":false,"profile_background_color":"FFF04D","lang":"en","profile_sidebar_border_color":"FFF8AD","profile_text_color":"333333","verified":false,"profile_image_url":"http://pbs.twimg.com/profile_images/741256000263577600/ECP0i84l_normal.jpg","time_zone":"London","url":"http://www.LeeHurst.com","contributors_enabled":false,"profile_background_tile":true,"statuses_count":22075,"follow_request_sent":null,"followers_count":41377,"profile_use_background_image":true,"default_profile":false,"following":null,"name":"Lee Hurst","location":"London","profile_sidebar_fill_color":"F6FFD1","notifications":null}},"retweet_count":0,"retweeted":false,"geo":null,"filter_level":"low","in_reply_to_screen_name":null,"is_quote_status":false,"id_str":"911531855555506177","in_reply_to_user_id":null,"favorite_count":0,"id":911531855555506177,"text":"RT @2010LeeHurst: This will be my final comment on #Brexit as it is now confirmed it is not happening. Now we wait for our imposed migrant\u2026","place":null,"lang":"en","quote_count":0,"favorited":false,"coordinates":null,"truncated":false,"timestamp_ms":"1506161104464","reply_count":0,"entities":{"urls":[],"hashtags":[{"indices":[51,58],"text":"Brexit"}],"user_mentions":[{"indices":[3,16],"screen_name":"2010LeeHurst","id_str":"141269460","name":"Lee Hurst","id":141269460}],"symbols":[]},"contributors":null,"user":{"utc_offset":null,"friends_count":157,"profile_image_url_https":"https://pbs.twimg.com/profile_images/743828464558612481/d29zqY3t_normal.jpg","listed_count":3,"profile_background_image_url":"","default_profile_image":false,"favourites_count":3942,"description":"Interested observer","created_at":"Wed Mar 09 12:39:19 +0000 2016","is_translator":false,"profile_background_image_url_https":"","protected":false,"screen_name":"WoottonDerek","id_str":"707546304784769024","profile_link_color":"1DA1F2","translator_type":"none","id":707546304784769024,"geo_enabled":false,"profile_background_color":"F5F8FA","lang":"en-GB","profile_sidebar_border_color":"C0DEED","profile_text_color":"333333","verified":false,"prof ...

# %% [markdown]
# To make things more easy to read we need to change the string read by line into JSON. We can use the JSON library from python to convert the regular string to a more readable JSON format.

# %%
first_line_json = json.loads(first_line)
print(json.dumps(first_line_json, indent=2))
# By default Pandas will limit the display of columns. This command will bypass the limit.
pd.set_option('display.max_columns', None)

tweets = []
df_tweet = pd.DataFrame()
df_tweet = df_tweet.append(json_normalize(first_line_json))
# Out:
# {
#   "in_reply_to_status_id_str": null,
#   "in_reply_to_status_id": null,
#   "created_at": "Sat Sep 23 10:05:04 +0000 2017",
#   "in_reply_to_user_id_str": null,
#   "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#   "retweeted_status": {
#     "in_reply_to_status_id_str": null,
#     "in_reply_to_status_id": null,
#     "created_at": "Sat Sep 23 09:59:13 +0000 2017",
#     "in_reply_to_user_id_str": null,
#     "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#     "retweet_count": 2,
#     "retweeted": false,
#     "geo": null,
#     "filter_level": "low",
#     "in_reply_to_screen_name": null,
#     "is_quote_status": false,
#     "id_str": "911530384046870528",
#     "in_reply_to_user_id": null,
#     "favorite_count": 0,
#     "id": 911530384046870528,
#     "text": "#Brexit will turn EU from equal partner to competitor with better trade deals worldwide &amp; a more attractive market 500 vs 65 Mln! #ScotRef",
#     "place": null,
#     "lang": "en",
#     "quote_count": 0,
#     "favorited": false,
#     "coordinates": null,
#     "truncated": false,
#     "reply_count": 0,
#     "entities": {
#       "urls": [],
#       "hashtags": [
#         {
#           "indices": [
#             0,
#             7
#           ],
#           "text": "Brexit"
#         },
#         {
#           "indices": [
#             134,
#             142
#           ],
#           "text": "ScotRef"
#         }
#       ],
#       "user_mentions": [],
#       "symbols": []
#     },
#     "contributors": null,
#     "user": {
#       "utc_offset": null,
#       "friends_count": 431,
#       "profile_image_url_https": "https://pbs.twimg.com/profile_images/593006236414701568/oOtWP0RA_normal.png",
#       "listed_count": 8,
#       "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#       "default_profile_image": false,
#       "favourites_count": 16108,
#       "description": "Love my family, guitars and Scotland. We must control the present and take the opportunity to commit though crimes.",
#       "created_at": "Tue Apr 28 10:53:41 +0000 2015",
#       "is_translator": false,
#       "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#       "protected": false,
#       "screen_name": "BigMarkyB",
#       "id_str": "3216761128",
#       "profile_link_color": "3B94D9",
#       "translator_type": "none",
#       "id": 3216761128,
#       "geo_enabled": true,
#       "profile_background_color": "000000",
#       "lang": "en",
#       "profile_sidebar_border_color": "000000",
#       "profile_text_color": "000000",
#       "verified": false,
#       "profile_image_url": "http://pbs.twimg.com/profile_images/593006236414701568/oOtWP0RA_normal.png",
#       "time_zone": null,
#       "url": "http://noisesfaetheheid.wordpress.com",
#       "contributors_enabled": false,
#       "profile_background_tile": false,
#       "profile_banner_url": "https://pbs.twimg.com/profile_banners/3216761128/1430239188",
#       "statuses_count": 8808,
#       "follow_request_sent": null,
#       "followers_count": 513,
#       "profile_use_background_image": false,
#       "default_profile": false,
#       "following": null,
#       "name": "Mark Breingan",
#       "location": "Cumbernauld, Scotland",
#       "profile_sidebar_fill_color": "000000",
#       "notifications": null
#     }
#   },
#   "retweet_count": 0,
#   "retweeted": false,
#   "geo": null,
#   "filter_level": "low",
#   "in_reply_to_screen_name": null,
#   "is_quote_status": false,
#   "id_str": "911531854305652738",
#   "in_reply_to_user_id": null,
#   "favorite_count": 0,
#   "id": 911531854305652738,
#   "text": "RT @BigMarkyB: #Brexit will turn EU from equal partner to competitor with better trade deals worldwide &amp; a more attractive market 500 vs 65\u2026",
#   "place": null,
#   "lang": "en",
#   "quote_count": 0,
#   "favorited": false,
#   "coordinates": null,
#   "truncated": false,
#   "timestamp_ms": "1506161104166",
#   "reply_count": 0,
#   "entities": {
#     "urls": [],
#     "hashtags": [
#       {
#         "indices": [
#           15,
#           22
#         ],
#         "text": "Brexit"
#       }
#     ],
#     "user_mentions": [
#       {
#         "indices": [
#           3,
#           13
#         ],
#         "screen_name": "BigMarkyB",
#         "id_str": "3216761128",
#         "name": "Mark Breingan",
#         "id": 3216761128
#       }
#     ],
#     "symbols": []
#   },
#   "contributors": null,
#   "user": {
#     "utc_offset": 0,
#     "friends_count": 174,
#     "profile_image_url_https": "https://pbs.twimg.com/profile_images/883058397511376896/iPCB67WM_normal.jpg",
#     "listed_count": 0,
#     "profile_background_image_url": "",
#     "default_profile_image": false,
#     "favourites_count": 924,
#     "description": "Hi, Robby really likes #scotref",
#     "created_at": "Fri Jun 30 19:43:33 +0000 2017",
#     "is_translator": false,
#     "profile_background_image_url_https": "",
#     "protected": false,
#     "screen_name": "fhathast_tha",
#     "id_str": "880874466393411585",
#     "profile_link_color": "1DA1F2",
#     "translator_type": "none",
#     "id": 880874466393411585,
#     "geo_enabled": false,
#     "profile_background_color": "F5F8FA",
#     "lang": "en-gb",
#     "profile_sidebar_border_color": "C0DEED",
#     "profile_text_color": "333333",
#     "verified": false,
#     "profile_image_url": "http://pbs.twimg.com/profile_images/883058397511376896/iPCB67WM_normal.jpg",
#     "time_zone": "UTC",
#     "url": null,
#     "contributors_enabled": false,
#     "profile_background_tile": false,
#     "profile_banner_url": "https://pbs.twimg.com/profile_banners/880874466393411585/1504050021",
#     "statuses_count": 5765,
#     "follow_request_sent": null,
#     "followers_count": 173,
#     "profile_use_background_image": true,
#     "default_profile": true,
#     "following": null,
#     "name": "Robby",
#     "location": "Scotland, United Kingdom",
#     "profile_sidebar_fill_color": "DDEEF6",
#     "notifications": null
#   }
# }

# %% [markdown]
# We can see how many columns the data has and how many column the tweet has.

# %%
print(df_tweet.columns)
print('There are {} columns for the tweet'.format(len(df_tweet.columns)))
# Out:
# Index(['contributors', 'coordinates', 'created_at', 'entities.hashtags',
#        'entities.symbols', 'entities.urls', 'entities.user_mentions',
#        'favorite_count', 'favorited', 'filter_level',
#        ...
#        'user.profile_text_color', 'user.profile_use_background_image',
#        'user.protected', 'user.screen_name', 'user.statuses_count',
#        'user.time_zone', 'user.translator_type', 'user.url', 'user.utc_offset',
#        'user.verified'],
#       dtype='object', length=135)
# There are 135 columns for the tweet

# %%
df_tweet
# Out:
#   contributors coordinates                      created_at  \
# 0         None        None  Sat Sep 23 10:05:04 +0000 2017
#
#                            entities.hashtags entities.symbols entities.urls  \
# 0  [{'indices': [15, 22], 'text': 'Brexit'}]               []            []
#
#                               entities.user_mentions  favorite_count  \
# 0  [{'indices': [3, 13], 'screen_name': 'BigMarky...               0
#
#    favorited filter_level   geo                  id              id_str  \
# 0      False          low  None  911531854305652738  911531854305652738
#
#   in_reply_to_screen_name in_reply_to_status_id in_reply_to_status_id_str  \
# 0                    None                  None                      None
#
#   in_reply_to_user_id in_reply_to_user_id_str  is_quote_status lang place  \
# 0                None                    None            False   en  None
#
#    quote_count  reply_count  retweet_count  retweeted  \
# 0            0            0              0      False
#
#   retweeted_status.contributors retweeted_status.coordinates  \
# 0                          None                         None
#
#       retweeted_status.created_at  \
# 0  Sat Sep 23 09:59:13 +0000 2017
#
#                   retweeted_status.entities.hashtags  \
# 0  [{'indices': [0, 7], 'text': 'Brexit'}, {'indi...
#
#   retweeted_status.entities.symbols retweeted_status.entities.urls  \
# 0                                []                             []
#
#   retweeted_status.entities.user_mentions  retweeted_status.favorite_count  \
# 0                                      []                                0
#
#    retweeted_status.favorited retweeted_status.filter_level  \
# 0                       False                           low
#
#   retweeted_status.geo  retweeted_status.id retweeted_status.id_str  \
# 0                 None   911530384046870528      911530384046870528
#
#   retweeted_status.in_reply_to_screen_name  \
# 0                                     None
#
#   retweeted_status.in_reply_to_status_id  \
# 0                                   None
#
#   retweeted_status.in_reply_to_status_id_str  \
# 0                                       None
#
#   retweeted_status.in_reply_to_user_id  \
# 0                                 None
#
#   retweeted_status.in_reply_to_user_id_str  retweeted_status.is_quote_status  \
# 0                                     None                             False
#
#   retweeted_status.lang retweeted_status.place  retweeted_status.quote_count  \
# 0                    en                   None                             0
#
#    retweeted_status.reply_count  retweeted_status.retweet_count  \
# 0                             0                               2
#
#    retweeted_status.retweeted  \
# 0                       False
#
#                              retweeted_status.source  \
# 0  <a href="http://twitter.com/download/iphone" r...
#
#                                retweeted_status.text  \
# 0  #Brexit will turn EU from equal partner to com...
#
#    retweeted_status.truncated  retweeted_status.user.contributors_enabled  \
# 0                       False                                       False
#
#   retweeted_status.user.created_at  retweeted_status.user.default_profile  \
# 0   Tue Apr 28 10:53:41 +0000 2015                                  False
#
#    retweeted_status.user.default_profile_image  \
# 0                                        False
#
#                    retweeted_status.user.description  \
# 0  Love my family, guitars and Scotland. We must ...
#
#    retweeted_status.user.favourites_count  \
# 0                                   16108
#
#   retweeted_status.user.follow_request_sent  \
# 0                                      None
#
#    retweeted_status.user.followers_count retweeted_status.user.following  \
# 0                                    513                            None
#
#    retweeted_status.user.friends_count  retweeted_status.user.geo_enabled  \
# 0                                  431                               True
#
#    retweeted_status.user.id retweeted_status.user.id_str  \
# 0                3216761128                   3216761128
#
#    retweeted_status.user.is_translator retweeted_status.user.lang  \
# 0                                False                         en
#
#    retweeted_status.user.listed_count retweeted_status.user.location  \
# 0                                   8          Cumbernauld, Scotland
#
#   retweeted_status.user.name retweeted_status.user.notifications  \
# 0              Mark Breingan                                None
#
#   retweeted_status.user.profile_background_color  \
# 0                                         000000
#
#   retweeted_status.user.profile_background_image_url  \
# 0   http://abs.twimg.com/images/themes/theme1/bg.png
#
#   retweeted_status.user.profile_background_image_url_https  \
# 0  https://abs.twimg.com/images/themes/theme1/bg.png
#
#    retweeted_status.user.profile_background_tile  \
# 0                                          False
#
#             retweeted_status.user.profile_banner_url  \
# 0  https://pbs.twimg.com/profile_banners/32167611...
#
#              retweeted_status.user.profile_image_url  \
# 0  http://pbs.twimg.com/profile_images/5930062364...
#
#        retweeted_status.user.profile_image_url_https  \
# 0  https://pbs.twimg.com/profile_images/593006236...
#
#   retweeted_status.user.profile_link_color  \
# 0                                   3B94D9
#
#   retweeted_status.user.profile_sidebar_border_color  \
# 0                                             000000
#
#   retweeted_status.user.profile_sidebar_fill_color  \
# 0                                           000000
#
#   retweeted_status.user.profile_text_color  \
# 0                                   000000
#
#    retweeted_status.user.profile_use_background_image  \
# 0                                              False
#
#    retweeted_status.user.protected retweeted_status.user.screen_name  \
# 0                            False                         BigMarkyB
#
#    retweeted_status.user.statuses_count retweeted_status.user.time_zone  \
# 0                                  8808                            None
#
#   retweeted_status.user.translator_type  \
# 0                                  none
#
#                retweeted_status.user.url retweeted_status.user.utc_offset  \
# 0  http://noisesfaetheheid.wordpress.com                             None
#
#    retweeted_status.user.verified  \
# 0                           False
#
#                                               source  \
# 0  <a href="http://twitter.com" rel="nofollow">Tw...
#
#                                                 text   timestamp_ms  \
# 0  RT @BigMarkyB: #Brexit will turn EU from equal...  1506161104166
#
#    truncated  user.contributors_enabled                 user.created_at  \
# 0      False                      False  Fri Jun 30 19:43:33 +0000 2017
#
#    user.default_profile  user.default_profile_image  \
# 0                  True                       False
#
#                   user.description  user.favourites_count  \
# 0  Hi, Robby really likes #scotref                    924
#
#   user.follow_request_sent  user.followers_count user.following  \
# 0                     None                   173           None
#
#    user.friends_count  user.geo_enabled             user.id  \
# 0                 174             False  880874466393411585
#
#           user.id_str  user.is_translator user.lang  user.listed_count  \
# 0  880874466393411585               False     en-gb                  0
#
#               user.location user.name user.notifications  \
# 0  Scotland, United Kingdom     Robby               None
#
#   user.profile_background_color user.profile_background_image_url  \
# 0                        F5F8FA
#
#   user.profile_background_image_url_https  user.profile_background_tile  \
# 0                                                                 False
#
#                              user.profile_banner_url  \
# 0  https://pbs.twimg.com/profile_banners/88087446...
#
#                               user.profile_image_url  \
# 0  http://pbs.twimg.com/profile_images/8830583975...
#
#                         user.profile_image_url_https user.profile_link_color  \
# 0  https://pbs.twimg.com/profile_images/883058397...                  1DA1F2
#
#   user.profile_sidebar_border_color user.profile_sidebar_fill_color  \
# 0                            C0DEED                          DDEEF6
#
#   user.profile_text_color  user.profile_use_background_image  user.protected  \
# 0                  333333                               True           False
#
#   user.screen_name  user.statuses_count user.time_zone user.translator_type  \
# 0     fhathast_tha                 5765            UTC                 none
#
#   user.url  user.utc_offset  user.verified
# 0     None                0          False

# %% [markdown]
# ## Put the rest of the JSON File to DataFrame

# %% [markdown]
# We only need certain columns though

# %%
df_tweets = pd.DataFrame()
with open(twitter_filename, 'r') as f:
    for line in f:
        tweet = json.loads(line)
        df_tweet = json_normalize(tweet)
        df_tweets = df_tweets.append(df_tweet.loc[:,['id','user.id', 'entities.hashtags','retweeted_status.retweet_count', 'text', 'user.followers_count']], ignore_index=True)
# Out:
# /Users/benapratama/miniconda3/envs/ds4d/lib/python3.6/site-packages/ipykernel_launcher.py:6: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#
# /Users/benapratama/miniconda3/envs/ds4d/lib/python3.6/site-packages/pandas/core/indexing.py:1367: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)

# %%
df_tweets.info()
print()
print ('we could double check the current state of the new data frame by using "info" command')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5735 entries, 0 to 5734
# Data columns (total 6 columns):
# id                                5735 non-null int64
# user.id                           5735 non-null int64
# entities.hashtags                 5735 non-null object
# retweeted_status.retweet_count    4134 non-null float64
# text                              5735 non-null object
# user.followers_count              5735 non-null int64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 268.9+ KB
#
# we could double check the current state of the new data frame by using "info" command

# %%
df_tweets.head()
# Out:
#                    id             user.id  \
# 0  911531854305652738  880874466393411585
# 1  911531855555506177  707546304784769024
# 2  911531855878295552  888726432221773824
# 3  911531857266610176  883617751666835458
# 4  911531866280341504  889420557590028288
#
#                                                                 entities.hashtags  \
# 0  [{'indices': [15, 22], 'text': 'Brexit'}]
# 1  [{'indices': [51, 58], 'text': 'Brexit'}]
# 2  [{'indices': [78, 81], 'text': 'EU'}, {'indices': [132, 137], 'text': 'Iran'}]
# 3  [{'indices': [78, 81], 'text': 'EU'}, {'indices': [132, 137], 'text': 'Iran'}]
# 4  [{'indices': [78, 81], 'text': 'EU'}, {'indices': [132, 137], 'text': 'Iran'}]
#
#    retweeted_status.retweet_count  \
# 0  2.0
# 1  372.0
# 2  135.0
# 3  136.0
# 4  137.0
#
#                                                                                                                                                text  \
# 0  RT @BigMarkyB: #Brexit will turn EU from equal partner to competitor with better trade deals worldwide &amp; a more attractive market 500 vs 65…
# 1  RT @2010LeeHurst: This will be my final comment on #Brexit as it is now confirmed it is not happening. Now we wait for our imposed migrant…
# 2  RT @Oceaanfietser: Any deal with Islamists terrorists in Tehran is illegal.If #EU politicians love islamists invite them to Europe, #Iran i…
# 3  RT @Oceaanfietser: Any deal with Islamists terrorists in Tehran is illegal.If #EU politicians love islamists invite them to Europe, #Iran i…
# 4  RT @Oceaanfietser: Any deal with Islamists terrorists in Tehran is illegal.If #EU politicians love islamists invite them to Europe, #Iran i…
#
#    user.followers_count
# 0  173
# 1  74
# 2  2
# 3  1
# 4  4

# %% [markdown]
# ## Top Retweet

# %%
def top_retweets(inputfile,k,n):
    # get all the tweets that has retweet count more than n times
    rt =  inputfile[inputfile['retweeted_status.retweet_count']>=n]
    # sort it accordingly, in descending order
    rt_sorted = rt.sort_values('retweeted_status.retweet_count',ascending=False)
    # return the top k entries
    return rt_sorted[:k]

# %% [markdown]
# So by creating a dictionary function we could get all the tweet that has retweet count more than 'n' times from the data frame. And then we could sort it according to the count value from the bigest to smallest.

# %%
output=top_retweets(df_tweets,10,25)
output
# Out:
#                       id             user.id  \
# 5638  911546619627175937  1160910768
# 5482  911546119104208896  2673414765
# 5291  911545509889888256  457037653
# 5012  911544736107855872  4186306797
# 2598  911538203953438721  780328587924803586
# 5656  911546688011108352  125143408
# 5504  911546196040339457  358122099
# 5496  911546168773152768  5794532
# 5381  911545774743355392  4105039342
# 5190  911545205458980869  14932463
#
#                                                                                                                                                                                                                                                                                                                                                 entities.hashtags  \
# 5638  []
# 5482  [{'indices': [21, 28], 'text': 'Brexit'}]
# 5291  [{'indices': [21, 28], 'text': 'Brexit'}]
# 5012  [{'indices': [21, 28], 'text': 'Brexit'}]
# 2598  [{'indices': [66, 80], 'text': 'PrayForBiafra'}, {'indices': [81, 96], 'text': 'FreeNnamdikanu'}, {'indices': [97, 117], 'text': 'MakeBiafraFreeAgain'}, {'indices': [118, 121], 'text': 'UN'}, {'indices': [122, 125], 'text': 'AU'}, {'indices': [126, 129], 'text': 'EU'}, {'indices': [130, 133], 'text': 'US'}, {'indices': [134, 137], 'text': 'UK'}]
# 5656  [{'indices': [21, 28], 'text': 'Brexit'}]
# 5504  [{'indices': [21, 28], 'text': 'Brexit'}]
# 5496  [{'indices': [21, 28], 'text': 'Brexit'}]
# 5381  [{'indices': [21, 28], 'text': 'Brexit'}]
# 5190  [{'indices': [21, 28], 'text': 'Brexit'}]
#
#       retweeted_status.retweet_count  \
# 5638  28291.0
# 5482  6737.0
# 5291  6736.0
# 5012  6735.0
# 2598  5035.0
# 5656  1555.0
# 5504  1555.0
# 5496  1554.0
# 5381  1553.0
# 5190  1552.0
#
#                                                                                                                                                      text  \
# 5638  RT @finance_LL: I'm going to cancel Netflix and negotiate with each film producer separately, to get the best deal for me and my family #Br…
# 5482  RT @ComedyCentralUK: #Brexit: A Titanic Failure https://t.co/ocdgEUCJDA
# 5291  RT @ComedyCentralUK: #Brexit: A Titanic Failure https://t.co/ocdgEUCJDA
# 5012  RT @ComedyCentralUK: #Brexit: A Titanic Failure https://t.co/ocdgEUCJDA
# 2598  RT @NkirukaNistoran: PLS JOIN US LIVE \nON RBL\nNEWS HOUR\nEVERY 7PM\n#PrayForBiafra\n#FreeNnamdikanu\n#MakeBiafraFreeAgain\n#UN #AU #EU #US #UK h…
# 5656  RT @CraigWhitington: #Brexit - When should the UK leave? \nPlease vote and RT. 🇬🇧🇪🇺
# 5504  RT @CraigWhitington: #Brexit - When should the UK leave? \nPlease vote and RT. 🇬🇧🇪🇺
# 5496  RT @CraigWhitington: #Brexit - When should the UK leave? \nPlease vote and RT. 🇬🇧🇪🇺
# 5381  RT @CraigWhitington: #Brexit - When should the UK leave? \nPlease vote and RT. 🇬🇧🇪🇺
# 5190  RT @CraigWhitington: #Brexit - When should the UK leave? \nPlease vote and RT. 🇬🇧🇪🇺
#
#       user.followers_count
# 5638  699
# 5482  651
# 5291  176
# 5012  1702
# 2598  148
# 5656  1047
# 5504  299
# 5496  557
# 5381  413
# 5190  582

# %% [markdown]
# ### Visualise the top retweets histogram

# %%
x_axis = ('a','b','c','d','e','f','g','h','i','j')

# %%
y_axis = output['retweeted_status.retweet_count'].astype(int).values.tolist()
print (y_axis)
# Out:
# [28291, 6737, 6736, 6735, 5035, 1555, 1555, 1554, 1553, 1552]

# %%
font = {'family': 'serif',
        'color':  'darkred',
        'weight': 'normal',
        'size': 10,
        }

plt.text('d', 25000, r'a = 911546619627175937 ', fontdict=font)
plt.text('d', 23800, r'b = 911546119104208896 ', fontdict=font)
plt.text('d', 22700, r'c = 911545509889888256 ', fontdict=font)
plt.text('d', 21500, r'd = 911544736107855872 ', fontdict=font)
plt.text('d', 20300, r'e = 911538203953438721 ', fontdict=font)
plt.text('d', 19100, r'f = 911546688011108352', fontdict=font)
plt.text('d', 17900, r'g = 911546196040339457 ', fontdict=font)
plt.text('d', 16700, r'h = 911546168773152768 ', fontdict=font)
plt.text('d', 15500, r'i = 911545774743355392 ', fontdict=font)
plt.text('d', 14300, r'j = 911545205458980869 ', fontdict=font)
plt.bar(x_axis,y_axis)
plt.title('Total Retweet Distribution',fontsize=16)
plt.xlabel('Tweet ID',fontsize=14)
plt.ylabel('Retweet Count',fontsize=14)
plt.show()
print ()

# %% [markdown]
# In this bar chart one perticular user reach above 25.000 retweet count. while most of the user did not reach 10.000 retweet count.

# %% [markdown]
# ### Tweet that has most retweeted count

# %%
mostRT = output['text'].iloc[0]
pd.set_option('display.max_colwidth',-1)
mostRT
# Out:
# "RT @finance_LL: I'm going to cancel Netflix and negotiate with each film producer separately, to get the best deal for me and my family #Br…"

# %% [markdown]
# ### Top RT againts follower count

# %%
x_axis = output['user.followers_count']

# %%
y_axis = output['retweeted_status.retweet_count'].astype(int).values.tolist()

# %%
plt.scatter(x_axis,y_axis)
plt.title('Total Retweet Distribution',fontsize=16)
plt.xlabel('Follower Count',fontsize=14)
plt.ylabel('Retweet Count',fontsize=14)
plt.show()

# %% [markdown]
# In this particular sample of 2017-09-23:11:05:01 twitter data we could see in this scatter plot that follower count and retweet count argueably does not have any liniear relationships.

# %% [markdown]
# ## Top Hashtags

# %%
def top_hashtags(inputfile,k):
    # extract hashtag entities from each entry
    entries =  inputfile['entities.hashtags']
    # create dictionary to count the hashtag appearance
    dict_ht = {}
    for entry in entries: # for each line in our input
        for ht in entry: # for every hashtag in each line
            # extract hashtags entities    
            dict_ht[ht['text']] = 1 + dict_ht.get(ht['text'],0)
          
    # sort it accordingly, in descending order
    ht_sorted = [(ht,dict_ht[ht]) for ht in sorted(dict_ht,key=dict_ht.get,reverse=True)]
    # return the top k entries
    return ht_sorted[:k]

# %%
output1 = top_hashtags(output,10)
output1
# Out:
# [('Brexit', 8),
#  ('PrayForBiafra', 1),
#  ('FreeNnamdikanu', 1),
#  ('MakeBiafraFreeAgain', 1),
#  ('UN', 1),
#  ('AU', 1),
#  ('EU', 1),
#  ('US', 1),
#  ('UK', 1)]

# %%
print ('most used hashtag in Top Retweet is : Brexit')
# Out:
# most used hashtag in Top Retweet is : Brexit

# %% [markdown]
# ### Visualise most used hashtag

# %%
x_axis1 = []
y_axis1 = []
for item in output1:
    x_axis1.append(item[0])
    y_axis1.append(item[1])

# %%
plt.bar(x_axis1,y_axis1)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Top Hashtags in  The Data Frame

# %%
def top_hashtags(inputfile,k):
    # extract hashtag entities from each entry
    entries =  inputfile['entities.hashtags']
    # create dictionary to count the hashtag appearance
    dict_ht = {}
    for entry in entries: # for each line in our input
        for ht in entry: # for every hashtag in each line
            # extract hashtags entities    
            dict_ht[ht['text']] = 1 + dict_ht.get(ht['text'],0)
          
    # sort it accordingly, in descending order
    ht_sorted = [(ht,dict_ht[ht]) for ht in sorted(dict_ht,key=dict_ht.get,reverse=True)]
    # return the top k entries
    return ht_sorted[:k]

# %%
output2 = top_hashtags(df_tweets,10)
output2
# Out:
# [('Brexit', 1801),
#  ('EU', 1219),
#  ('Iran', 648),
#  ('brexit', 355),
#  ('Referendum', 216),
#  ('florencespeech', 200),
#  ('Remain', 159),
#  ('Europe', 150),
#  ('referendum', 145),
#  ('StopBrexit', 108)]

# %% [markdown]
# ### Visualise most used hashtag in the data frame

# %%
x_axis2 = []
y_axis2 = []
for item in output2:
    x_axis2.append(item[0])
    y_axis2.append(item[1])

# %%
f = plt.figure(5,figsize=(12,6))
plt.subplot(121)
plt.title('Top Hashtags',fontsize=16)
plt.bar(x_axis2,y_axis2)
plt.xticks(rotation=90)


plt.subplot(122)
plt.title('Top Hashtags in Top Retweet',fontsize=16)
plt.bar(x_axis1,y_axis1)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# We could see that #Brexit does really popular in both data sample followed by #EU in second place in almost 1250 appearance count. Eventhough it only appear once in the Top Hashtags in Top Retweet data sample.

# %% [markdown]
# ## Reflect & Hypothesis

# %% [markdown]
# With this project comes to a conclussions I found that the followers a user have, possibly does not directly corelate to how many times their tweets being retweeted. Also in this topic #brexit argueably is the most used hashtag. By slicing the pandas we could get a layered result.
