# %%
import json
import pandas as pd
import numpy as np
from pandas.io.json import json_normalize

# Pandas by default limit the maximum columns display. This will remove the limit.
pd.set_option('display.max_columns', None)

tweets = []
df = pd.DataFrame()

# %%
twitter_filename = "2017-09-22:03:05:01.json"
twitter_file = open(twitter_filename, 'r')

# %%
selected_columns = ['id_str',
                    'created_at', 
                    'text', 
                    'entities.hashtags', 
                    'lang',
                    'user.screen_name', 
                    'user.id_str',
                    'user.followers_count',
                    'user.friends_count',
                    'retweeted_status.id_str',
                    'retweeted_status.created_at',
                    'retweeted_status.text',
                    'retweeted_status.entities.hashtags',
                    'retweeted_status.lang',
                    'retweeted_status.user.screen_name',
                    'retweeted_status.user.id_str',
                    'retweeted_status.user.followers_count',
                    'retweeted_status.user.friends_count']

# %%
df_tweets = pd.DataFrame()
with open(twitter_filename, 'r') as f:
    for line in f:
        tweet = json.loads(line)
        df = json_normalize(tweet)
        df_tweets = df_tweets.append(df.loc[:,selected_columns], ignore_index=True)

# %%
df_tweets.count()
# Out:
# id_str                                   748
# created_at                               748
# text                                     748
# entities.hashtags                        748
# lang                                     748
# user.screen_name                         748
# user.id_str                              748
# user.followers_count                     748
# user.friends_count                       748
# retweeted_status.id_str                  341
# retweeted_status.created_at              341
# retweeted_status.text                    341
# retweeted_status.entities.hashtags       341
# retweeted_status.lang                    341
# retweeted_status.user.screen_name        341
# retweeted_status.user.id_str             341
# retweeted_status.user.followers_count    341
# retweeted_status.user.friends_count      341
# dtype: int64

# %%
#df_tweets.tail()

# %%
def convert_hashtags(entries):
    hashtags = []
#     print (entries)
    if (entries != "NO HASHTAGS"): 
        if (len(entries) == 0):
            return "NO HASHTAGS"
        else:
            for entry in entries: # for each line in our input
    #             print(entry['text'])
    #             for ht in entry: # for every hashtag in each line
    #                 print (ht)
                hashtags.append(entry['text'])
            return hashtags
    else:
        return "NO HASHTAGS"

# %%
df_tweets['entities.hashtags'] = df_tweets['entities.hashtags'].astype('object').fillna("No Hashtags")
df_tweets['retweeted_status.entities.hashtags'] = df_tweets['retweeted_status.entities.hashtags'].astype('object').fillna("NO HASHTAGS")

# %%
df_tweets['retweeted_status.entities.hashtags'] = df_tweets['retweeted_status.entities.hashtags'].apply(lambda row: convert_hashtags(row))
df_tweets['entities.hashtags'] = df_tweets['entities.hashtags'].apply(lambda row: convert_hashtags(row))

# %%
df_tweets.to_csv("export_2016062306.csv", sep=',', encoding='utf-8')

# %%
df_tweets2 = pd.read_csv('export_2016062306.csv', index_col = 0)

# %% [markdown]
# Setting random value for sentiment and sentiment_ori

# %%
df_tweets2['sentiment'] = np.random.uniform(-1,1, size=len(df_tweets2))
df_tweets2['sentiment_ori'] = np.random.uniform(-1,1, size=len(df_tweets2))

# %% [markdown]
# Setting random value for bot status

# %%
df_tweets2['bot_status'] = np.random.uniform(0,1, size=len(df_tweets2))
df_tweets2['bot_ori_status'] = np.random.uniform(0,1, size=len(df_tweets2))

# %%
df_tweets2
# Out:
#                  id_str                      created_at  \
# 0    911048657474113536  Fri Sep 22 02:05:01 +0000 2017
# 1    911048676205826048  Fri Sep 22 02:05:05 +0000 2017
# 2    911048690529431552  Fri Sep 22 02:05:08 +0000 2017
# 3    911048692567760896  Fri Sep 22 02:05:09 +0000 2017
# 733  Later today @theresa_may will deliver a #Brexi...
# 734  Deadly fire engulfs Russian hotel #news #eu ht...
# 735  #Trump &amp; #CNN, the piece #bothsides hate. ...
# 736  hfTLCS #Brexit #TTIP #Путин #FF #киев #политик...
# 737  Every person deserves to be safe, happy, healt...
# 738  RT @MaldenSaboteur: #bbctw Tim Martin (Wethers...
# 739  RT @vrstardiaries: 5 Beautiful Places You Shou...
# 740  ＥＵ離脱交渉、進展には英の確固たる提案必要＝バルニエ交渉官 https://t.co/JyD...
# 741  There is just ☝️ Islam ☝️ message 💀❗️their lea...
# 742  .@realDonaldTrump Syrian refugees deserve safe...
# 743  RT @eerickarchila: follow me - Catalan leader ...
# 744  RT @champagne_lefty: Those who question #Brexi...
# 745  Every person deserves to be safe, happy, healt...
# 746  RT @eerickarchila: follow me - Catalan leader ...
# 747  Michael Heseltine: #Brexit won't happen and we...
#
#                                      entities.hashtags lang user.screen_name  \
# 0                        ['EU', 'News', 'EuropeUnion']   fr        nathymora
# 1                        ['EU', 'News', 'EuropeUnion']   en      EuropeUnion
# 2                        ['EU', 'News', 'EuropeUnion']   en        nathymora
# 3    ['buddhism', 'buddhist', 'europe', 'canada', '...   en  KumarTa69783205
# 4                                           ['Brexit']   en  SergioTavaresUK
# 5                                           ['Brexit']   en  keira_churchill
# 6                                      ['September30']   en     randy_barnes
# 7                                           ['Brexit']   en     jbwhitesnake
# 8                ['EU', 'Rusland', 'Syrien', 'Bashar']   no        TooglesDK
# 9    ['Spagna', 'indipendentisti', 'GuardiaCivil', ...   it        Nenufar87
# 10                                   ['FBA', 'Europe']   en       FBA_EUROPE
# 11                                          ['Brexit']   en           woifim
# 12                                          ['Brexit']   en           woifim
# 13                                         NO HASHTAGS   en       sousibrown
# 14                           ['eu', 'leave', 'brexit']   en           woifim
# 15        ['vote', 'vote', 'CASECLOSED', 'REFERENDUM']   en    SamSamjonesel
# 16   ['Ask108', 'Divination', 'KlaudioZic', 'Tradin...   en           woifim
# 17                  ['gbpaud', 'GBP', 'aud', 'brexit']   en           woifim
# 18                                        ['EU', 'PM']   en   ricker_carolyn
# 19                     ['Brexit', 'WorldNews', 'News']   en           woifim
# 20                     ['Brexit', 'WorldNews', 'News']   en           woifim
# 21                ['RefugeesWelcome', '1DayWithoutUs']   en     mjbballlover
# 22   ['EU', 'Austria', 'Belgium', 'Portgal', 'Irela...   en    Truth_of_HELL
# 23                                         NO HASHTAGS   en           uxonym
# 24                                          ['Brexit']   en       siman_hadi
# 25                                       ['EU', 'VAW']   en      MacarenaSWS
# 26                     ['travel', 'Spain', 'Asturias']   en       uprun4life
# 27   ['Kimchi', 'un', 'eu', 'nato', 'asean', 'nyt',...   en     JILL27595792
# 28                                         NO HASHTAGS   en      jamieainnes
# 29                                         NO HASHTAGS   en  elizabe95815732
# ..                                                 ...  ...              ...
# 718      ['Catalonia', 'ScotsForCatalonia', 'ScotRef']   en     CatalanRobot
# 719                                         ['brexit']   en      emmie_madam
# 720           ['MSM', 'conservatives', 'MAGA', 'tcot']   en         LbrtyNow
# 721             ['LatestNews', 'brexit', 'bbcnewssix']   en         TaitNews
# 722  ['interracial', 'EU', 'openborders', 'refugees...   en          romne20
# 723                          ['CommonSense', 'Brexit']   en            Zjay8
# 724                     ['referendum', 'myFirstTweet']   en    RasyidjhMovie
# 725                                 ['Brexit', 'EU離脱']   ja    PwC_JP_Brexit
# 726                                         ['Europe']   en       waterstars
# 727                                         ['Brexit']   en     julietlodge2
# 728        ['YYJ', 'AggregateIQ', 'Brexit', 'cdnpoli']   en       xSerafinii
# 729  ['HandCraft', 'crafts', 'craftshop', 'giftshop...   en     topukdealers
# 730                                        NO HASHTAGS   en          Cadoret
# 731                                         ['Europe']   en      winvest2311
# 732  ['Hitler', 'Goebbels', 'ThirdReich', 'National...   en   YoureaMarxist1
# 733                                         ['Brexit']   en         uk_rants
# 734                                     ['news', 'eu']   en      Brexitnews1
# 735  ['Trump', 'CNN', 'bothsides', 'PhoenixRally', ...   en       RichKelsey
# 736  ['Brexit', 'TTIP', 'Путин', 'FF', 'киев', 'пол...   en       abbyrabbyi
# 737               ['RefugeesWelcome', '1DayWithoutUs']   en   DAVIDEDUARDOJL
# 738                                ['bbctw', 'Brexit']   en  asymetricjockey
# 739                    ['travel', 'Spain', 'Asturias']   en    sammyapproves
# 740                                 ['Brexit', 'EU離脱']   ja    PwC_JP_Brexit
# 741                                        NO HASHTAGS   en  thakuracharyaom
# 742               ['GlobalCitizen', 'RefugeesWelcome']   en       anupreet79
# 743                   ['Catalonia', 'Spain', 'Europe']   en    harry1911foot
# 744                                         ['Brexit']   en  sound_of_sirens
# 745               ['RefugeesWelcome', '1DayWithoutUs']   en       anupreet79
# 746                   ['Catalonia', 'Spain', 'Europe']   en     CatalanRobot
# 747                                         ['Brexit']   en        JumMurphy
#
#             user.id_str  user.followers_count  user.friends_count  \
# 0             308046422                   611                 404
# 1             194119186                  9489                 586
# 2             308046422                   611                 404
# 3    882043107776184320                    18                  56
# 4            2178018878                   203                 418
# 5    730602471979159552                  1552                1202
# 6             237750885                   188                 130
# 7             200818199                  7698                8212
# 8    838661199474589696                    23                  14
# 9            3221849296                    33                 236
# 10           2643740437                  6183                6802
# 11           1331204348                  1135                1001
# 12           1331204348                  1135                1001
# 13            401060976                  1164                1479
# 14           1331204348                  1135                1001
# 15           3015273017                  1885                2926
# 16           1331204348                  1135                1001
# 17           1331204348                  1135                1001
# 18           2238532361                   144                 124
# 19           1331204348                  1135                1001
# 20           1331204348                  1135                1001
# 21           2489186636                    82                  10
# 22           4592980152                  1178                1072
# 23            277223742                   272                 720
# 24           3224058864                   193                 164
# 25            482772386                  1045                1322
# 26           3262013592                  8627                6662
# 27   717717142217445377                 11835               12192
# 28            221051542                   202                 396
# 29           2343718973                   598                 152
# ..                  ...                   ...                 ...
# 718  905779194088579072                   142                   1
# 719           106229637                   334                   2
# 720           559623797                 15978               15839
# 721          3163496663                    15                 160
# 722  893136851137179650                   108                 679
# 723          1098182053                   215                 578
# 724  703251671476936705                  2284                2642
# 725  760394988547022848                   245                 514
# 726            61848222                   210                 439
# 727          1425210032                  1365                1533
# 728           266792620                   179                 154
# 729  754830458089775104                  4835                4349
# 730            24863992                   876                 270
# 731            38597613                 30451                 105
# 732  899050344184938496                   358                 622
# 733          3011256515                  8398                7108
# 734  840533427740909568                   822                2810
# 735            98993077                  1996                1830
# 736  867443047935733762                  2335                 500
# 737           210786621                   198                 554
# 738           164809116                   717                 784
# 739            91135990                 26595               20918
# 740  760394988547022848                   245                 514
# 741  858340765533077504                  2026                3424
# 742          1157802895                    18                  70
# 743  893465262737043456                     2                  13
# 744           128929917                   305                 181
# 745          1157802895                    18                  70
# 746  905779194088579072                   142                   1
# 747          3019712643                  5997                4743
#
#      retweeted_status.id_str     retweeted_status.created_at  \
# 0                        NaN                             NaN
# 1                        NaN                             NaN
# 2                        NaN                             NaN
# 3               9.099393e+17  Tue Sep 19 00:36:41 +0000 2017
# 4                        NaN                             NaN
# 5                        NaN                             NaN
# 6               9.110374e+17  Fri Sep 22 01:20:11 +0000 2017
# 7               9.109327e+17  Thu Sep 21 18:24:18 +0000 2017
# 8                        NaN                             NaN
# 9               9.105056e+17  Wed Sep 20 14:07:06 +0000 2017
# 10                       NaN                             NaN
# 11              9.110487e+17  Fri Sep 22 02:05:15 +0000 2017
# 12              9.110487e+17  Fri Sep 22 02:05:14 +0000 2017
# 13                       NaN                             NaN
# 14              9.110486e+17  Fri Sep 22 02:04:41 +0000 2017
# 15              9.108626e+17  Thu Sep 21 13:45:40 +0000 2017
# 16              9.110485e+17  Fri Sep 22 02:04:20 +0000 2017
# 17              9.110485e+17  Fri Sep 22 02:04:19 +0000 2017
# 18              9.109386e+17  Thu Sep 21 18:47:39 +0000 2017
# 19              9.110485e+17  Fri Sep 22 02:04:16 +0000 2017
# 20              9.110485e+17  Fri Sep 22 02:04:12 +0000 2017
# 21                       NaN                             NaN
# 22                       NaN                             NaN
# 23              9.082565e+17  Thu Sep 14 09:09:54 +0000 2017
# 24                       NaN                             NaN
# 25                       NaN                             NaN
# 26              9.108639e+17  Thu Sep 21 13:50:44 +0000 2017
# 27                       NaN                             NaN
# 28              9.109337e+17  Thu Sep 21 18:28:05 +0000 2017
# 29              9.110451e+17  Fri Sep 22 01:50:47 +0000 2017
# ..                       ...                             ...
# 718             9.109013e+17  Thu Sep 21 16:19:38 +0000 2017
# 719                      NaN                             NaN
# 720                      NaN                             NaN
# 721                      NaN                             NaN
# 722             9.044225e+17  Sun Sep 03 19:15:09 +0000 2017
# 723             9.110252e+17  Fri Sep 22 00:31:56 +0000 2017
# 724                      NaN                             NaN
# 725                      NaN                             NaN
# 726             9.110461e+17  Fri Sep 22 01:55:01 +0000 2017
# 727             9.108817e+17  Thu Sep 21 15:01:40 +0000 2017
# 728                      NaN                             NaN
# 729                      NaN                             NaN
# 730             8.615078e+17  Mon May 08 09:07:30 +0000 2017
# 731                      NaN                             NaN
# 732             9.109006e+17  Thu Sep 21 16:16:45 +0000 2017
# 733                      NaN                             NaN
# 734                      NaN                             NaN
# 735                      NaN                             NaN
# 736                      NaN                             NaN
# 737                      NaN                             NaN
# 738             9.110036e+17  Thu Sep 21 23:05:52 +0000 2017
# 739             9.108639e+17  Thu Sep 21 13:50:44 +0000 2017
# 740                      NaN                             NaN
# 741                      NaN                             NaN
# 742                      NaN                             NaN
# 743             9.110480e+17  Fri Sep 22 02:02:34 +0000 2017
# 744             9.108427e+17  Thu Sep 21 12:26:25 +0000 2017
# 745                      NaN                             NaN
# 746             9.110480e+17  Fri Sep 22 02:02:34 +0000 2017
# 747                      NaN                             NaN
#
#                                  retweeted_status.text  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3    Three art styles to see! https://t.co/sD090hDa...
# 4                                                  NaN
# 5                                                  NaN
# 6    Dear @gop -I will keep it simple: JUST REPEAL ...
# 7    Rumour has it the Magic Money Tree is going to...
# 8                                                  NaN
# 9    #Spagna, scontri violenti tra #indipendentisti...
# 10                                                 NaN
# 11   Brexiteers are not necessarily fleeing from Ma...
# 12             Thread. #Brexit https://t.co/oG4MqhTJMt
# 13                                                 NaN
# 14   Theresa May must show that we mean business af...
# 15   Biafrans terrorists do not #vote, we should no...
# 16   #Ask108 questions https://t.co/hBbw2EyAUc #Div...
# 17   Short #gbpaud intraday before brexit speech en...
# 18   #EU believes #PM's rumoured offer is too low 😳...
# 19   The UK’s #Brexit hostage https://t.co/b9EA9Dmd...
# 20   Florence #Brexit speech: An overdue opportunit...
# 21                                                 NaN
# 22                                                 NaN
# 23   I'm going to cancel Netflix and negotiate with...
# 24                                                 NaN
# 25                                                 NaN
# 26   5 Beautiful Places You Should Visit in Asturia...
# 27                                                 NaN
# 28   CETA comes into effect today and we're pleased...
# 29   Here is Labour, this is what they've been for ...
# ..                                                 ...
# 718  A growing army of Scots will stand with you #C...
# 719                                                NaN
# 720                                                NaN
# 721                                                NaN
# 722  Diversity is Beautiful #interracial #EU #openb...
# 723  This country is known for its #CommonSense.\nI...
# 724                                                NaN
# 725                                                NaN
# 726  Will I ever get sick of sharing exaggerated re...
# 727  Absolutely spot on from @MollyMEP. Government ...
# 728                                                NaN
# 729                                                NaN
# 730  The UK economy grew faster after joining the E...
# 731                                                NaN
# 732  National Socialist 卐 Family Picture\n#Hitler #...
# 733                                                NaN
# 734                                                NaN
# 735                                                NaN
# 736                                                NaN
# 737                                                NaN
# 738  #bbctw Tim Martin (Wetherspoons) having his ar...
# 739  5 Beautiful Places You Should Visit in Asturia...
# 740                                                NaN
# 741                                                NaN
# 742                                                NaN
# 743  follow me - Catalan leader accuses Spain of vi...
# 744  Those who question #Brexit are unbelievers and...
# 745                                                NaN
# 746  follow me - Catalan leader accuses Spain of vi...
# 747                                                NaN
#
#                     retweeted_status.entities.hashtags retweeted_status.lang  \
# 0                                          NO HASHTAGS                   NaN
# 1                                          NO HASHTAGS                   NaN
# 2                                          NO HASHTAGS                   NaN
# 3    ['buddhism', 'buddhist', 'europe', 'canada', '...                    en
# 4                                          NO HASHTAGS                   NaN
# 5                                          NO HASHTAGS                   NaN
# 6                   ['September30', 'VOTEOUT', 'MAGA']                    en
# 7                                           ['Brexit']                    en
# 8                                          NO HASHTAGS                   NaN
# 9    ['Spagna', 'indipendentisti', 'GuardiaCivil', ...                    it
# 10                                         NO HASHTAGS                   NaN
# 11                                          ['Brexit']                    en
# 12                                          ['Brexit']                    en
# 13                                         NO HASHTAGS                   NaN
# 14                           ['eu', 'leave', 'brexit']                    en
# 15        ['vote', 'vote', 'CASECLOSED', 'REFERENDUM']                    en
# 16   ['Ask108', 'Divination', 'KlaudioZic', 'Tradin...                    en
# 17                  ['gbpaud', 'GBP', 'aud', 'brexit']                    en
# 18                                        ['EU', 'PM']                    en
# 19                     ['Brexit', 'WorldNews', 'News']                    en
# 20                     ['Brexit', 'WorldNews', 'News']                    en
# 21                                         NO HASHTAGS                   NaN
# 22                                         NO HASHTAGS                   NaN
# 23                                          ['Brexit']                    en
# 24                                         NO HASHTAGS                   NaN
# 25                                         NO HASHTAGS                   NaN
# 26   ['travel', 'Spain', 'Asturias', 'Europe', 'lan...                    en
# 27                                         NO HASHTAGS                   NaN
# 28                                         NO HASHTAGS                    en
# 29                                         NO HASHTAGS                    en
# ..                                                 ...                   ...
# 718      ['Catalonia', 'ScotsForCatalonia', 'ScotRef']                    en
# 719                                        NO HASHTAGS                   NaN
# 720                                        NO HASHTAGS                   NaN
# 721                                        NO HASHTAGS                   NaN
# 722  ['interracial', 'EU', 'openborders', 'refugees...                    en
# 723                          ['CommonSense', 'Brexit']                    en
# 724                                        NO HASHTAGS                   NaN
# 725                                        NO HASHTAGS                   NaN
# 726                                         ['Europe']                    en
# 727                                         ['Brexit']                    en
# 728                                        NO HASHTAGS                   NaN
# 729                                        NO HASHTAGS                   NaN
# 730                                        NO HASHTAGS                    en
# 731                                        NO HASHTAGS                   NaN
# 732  ['Hitler', 'Goebbels', 'ThirdReich', 'National...                    en
# 733                                        NO HASHTAGS                   NaN
# 734                                        NO HASHTAGS                   NaN
# 735                                        NO HASHTAGS                   NaN
# 736                                        NO HASHTAGS                   NaN
# 737                                        NO HASHTAGS                   NaN
# 738                                ['bbctw', 'Brexit']                    en
# 739  ['travel', 'Spain', 'Asturias', 'Europe', 'lan...                    en
# 740                                        NO HASHTAGS                   NaN
# 741                                        NO HASHTAGS                   NaN
# 742                                        NO HASHTAGS                   NaN
# 743                   ['Catalonia', 'Spain', 'Europe']                    en
# 744                                         ['Brexit']                    en
# 745                                        NO HASHTAGS                   NaN
# 746                   ['Catalonia', 'Spain', 'Europe']                    en
# 747                                        NO HASHTAGS                   NaN
#
#     retweeted_status.user.screen_name  retweeted_status.user.id_str  \
# 0                                 NaN                           NaN
# 1                                 NaN                           NaN
# 2                                 NaN                           NaN
# 3                           tsemtulku                  2.306588e+07
# 4                                 NaN                           NaN
# 5                                 NaN                           NaN
# 6                         WAGNERGIRLE                  2.245651e+07
# 7                      RebetikoWalrus                  1.448272e+08
# 8                                 NaN                           NaN
# 9                     gabrieleimperia                  2.570391e+09
# 10                                NaN                           NaN
# 11                    keira_churchill                  7.306025e+17
# 12                    SergioTavaresUK                  2.178019e+09
# 13                                NaN                           NaN
# 14                         devototone                  1.032420e+09
# 15                         MurffyJohn                  7.258706e+17
# 16                        prO5pero222                  7.221114e+17
# 17                         Corsicasia                  2.214130e+09
# 18                    EUVoteLeave23rd                  7.018666e+17
# 19                            Anon_Eu                  8.138995e+08
# 20                            Anon_Eu                  8.138995e+08
# 21                                NaN                           NaN
# 22                                NaN                           NaN
# 23                         finance_LL                  1.562931e+08
# 24                                NaN                           NaN
# 25                                NaN                           NaN
# 26                      vrstardiaries                  3.250269e+09
# 27                                NaN                           NaN
# 28                      Clearwatersea                  3.575106e+08
# 29                          scarycath                  1.789668e+07
# ..                                ...                           ...
# 718                            Zen432                  9.533582e+08
# 719                               NaN                           NaN
# 720                               NaN                           NaN
# 721                               NaN                           NaN
# 722                   lnterracialLust                  7.235903e+17
# 723                       Bonn1eGreer                  6.115853e+08
# 724                               NaN                           NaN
# 725                               NaN                           NaN
# 726                    simongerman600                  3.591885e+08
# 727                     CarolineLucas                  8.080290e+07
# 728                               NaN                           NaN
# 729                               NaN                           NaN
# 730                   weloveeconomics                  8.518469e+17
# 731                               NaN                           NaN
# 732                    ExpandedGalaxy                  3.101986e+09
# 733                               NaN                           NaN
# 734                               NaN                           NaN
# 735                               NaN                           NaN
# 736                               NaN                           NaN
# 737                               NaN                           NaN
# 738                    MaldenSaboteur                  4.301251e+09
# 739                     vrstardiaries                  3.250269e+09
# 740                               NaN                           NaN
# 741                               NaN                           NaN
# 742                               NaN                           NaN
# 743                     eerickarchila                  8.134584e+17
# 744                   champagne_lefty                  3.310749e+09
# 745                               NaN                           NaN
# 746                     eerickarchila                  8.134584e+17
# 747                               NaN                           NaN
#
#      retweeted_status.user.followers_count  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                 452447.0
# 4                                      NaN
# 5                                      NaN
# 6                                  58062.0
# 7                                   2638.0
# 8                                      NaN
# 9                                   3307.0
# 10                                     NaN
# 11                                  1552.0
# 12                                   203.0
# 13                                     NaN
# 14                                   178.0
# 15                                  2201.0
# 16                                   446.0
# 17                                    40.0
# 18                                 19115.0
# 19                                 12973.0
# 20                                 12973.0
# 21                                     NaN
# 22                                     NaN
# 23                                  3354.0
# 24                                     NaN
# 25                                     NaN
# 26                                  1653.0
# 27                                     NaN
# 28                                  3184.0
# 29                                  2674.0
# ..                                     ...
# 718                                15081.0
# 719                                    NaN
# 720                                    NaN
# 721                                    NaN
# 722                                20016.0
# 723                                54814.0
# 724                                    NaN
# 725                                    NaN
# 726                                35000.0
# 727                               261896.0
# 728                                    NaN
# 729                                    NaN
# 730                                 2579.0
# 731                                    NaN
# 732                                 8012.0
# 733                                    NaN
# 734                                    NaN
# 735                                    NaN
# 736                                    NaN
# 737                                    NaN
# 738                                  993.0
# 739                                 1654.0
# 740                                    NaN
# 741                                    NaN
# 742                                    NaN
# 743                                  426.0
# 744                                 4269.0
# 745                                    NaN
# 746                                  426.0
# 747                                    NaN
#
#      retweeted_status.user.friends_count  sentiment  sentiment_ori  \
# 0                                    NaN   0.823204       0.889909
# 1                                    NaN   0.601482      -0.054060
# 2                                    NaN  -0.166085      -0.275917
# 3                                  169.0   0.460622       0.206314
# 4                                    NaN  -0.489391       0.806878
# 5                                    NaN   0.268814      -0.881223
# 6                                38115.0  -0.506119      -0.176075
# 7                                 1977.0   0.091227      -0.465043
# 8                                    NaN  -0.016554       0.183181
# 9                                 2427.0   0.350126      -0.407567
# 10                                   NaN  -0.755765      -0.556570
# 11                                1202.0  -0.784836      -0.645286
# 12                                 418.0  -0.712296      -0.173308
# 13                                   NaN  -0.254214      -0.475223
# 14                                  88.0  -0.398420      -0.598477
# 15                                  17.0  -0.971506      -0.584346
# 16                                 753.0   0.654870       0.465263
# 17                                   2.0  -0.647140      -0.680435
# 18                               21009.0   0.011677      -0.068610
# 19                                6864.0   0.959494      -0.628827
# 20                                6864.0   0.954053       0.615811
# 21                                   NaN   0.145326       0.252863
# 22                                   NaN   0.221651      -0.941129
# 23                                1033.0  -0.660493      -0.989062
# 24                                   NaN  -0.763333       0.280346
# 25                                   NaN   0.664895      -0.063411
# 26                                1149.0  -0.792678      -0.202646
# 27                                   NaN   0.300163       0.380624
# 28                                 748.0   0.635290       0.256395
# 29                                 952.0  -0.638397      -0.220654
# ..                                   ...        ...            ...
# 718                              14828.0   0.849700      -0.870920
# 719                                  NaN  -0.316291       0.230486
# 720                                  NaN   0.378096       0.765667
# 721                                  NaN   0.867634       0.319072
# 722                                463.0  -0.441754       0.523865
# 723                              18167.0   0.883867       0.371583
# 724                                  NaN  -0.863477       0.779717
# 725                                  NaN   0.040432       0.074029
# 726                              34219.0   0.755786       0.142790
# 727                               5023.0   0.863056      -0.713311
# 728                                  NaN  -0.381620       0.297831
# 729                                  NaN   0.130450      -0.965006
# 730                               1197.0   0.750537       0.397024
# 731                                  NaN   0.889011       0.607077
# 732                               8664.0   0.376501      -0.720204
# 733                                  NaN   0.441715       0.049151
# 734                                  NaN  -0.444131       0.340368
# 735                                  NaN  -0.029981      -0.093831
# 736                                  NaN  -0.958710       0.162273
# 737                                  NaN   0.971202      -0.029295
# 738                               1607.0  -0.175803       0.350205
# 739                               1149.0   0.864408      -0.325492
# 740                                  NaN   0.100309       0.014505
# 741                                  NaN   0.884063       0.992591
# 742                                  NaN   0.581346      -0.725126
# 743                               1119.0   0.301880       0.421729
# 744                               4968.0   0.285768      -0.209582
# 745                                  NaN  -0.110269      -0.195418
# 746                               1119.0  -0.276272       0.063131
# 747                                  NaN   0.969102      -0.529338
#
#      bot_status  bot_ori_status
# 0      0.032754        0.025925
# 1      0.360294        0.887084
# 2      0.048649        0.413533
# 3      0.199692        0.920356
# 4      0.019213        0.263571
# 5      0.917066        0.349116
# 6      0.073966        0.305804
# 7      0.259949        0.680447
# 8      0.026624        0.652662
# 9      0.750006        0.879370
# 10     0.079532        0.378749
# 11     0.986629        0.947211
# 12     0.617170        0.244364
# 13     0.370673        0.052861
# 14     0.947281        0.516369
# 15     0.871736        0.786001
# 16     0.384597        0.500414
# 17     0.179224        0.827118
# 18     0.354329        0.965268
# 19     0.239161        0.603809
# 20     0.032747        0.504043
# 21     0.947878        0.007159
# 22     0.481603        0.469370
# 23     0.945500        0.855033
# 24     0.909688        0.071397
# 25     0.556020        0.016977
# 26     0.502819        0.662590
# 27     0.566954        0.113093
# 28     0.104263        0.129010
# 29     0.316967        0.659225
# ..          ...             ...
# 718    0.318097        0.830482
# 719    0.163987        0.544834
# 720    0.475019        0.071456
# 721    0.089425        0.488322
# 722    0.483448        0.546398
# 723    0.967062        0.190432
# 724    0.851701        0.887104
# 725    0.026716        0.056239
# 726    0.844131        0.042868
# 727    0.946730        0.696148
# 728    0.139425        0.102290
# 729    0.931433        0.437343
# 730    0.842879        0.850343
# 731    0.853694        0.471019
# 732    0.469093        0.179884
# 733    0.574383        0.521618
# 734    0.193157        0.497120
# 735    0.347042        0.931892
# 736    0.145317        0.510003
# 737    0.866120        0.549443
# 738    0.207600        0.022400
# 739    0.135152        0.303404
# 740    0.137703        0.078030
# 741    0.920126        0.772263
# 742    0.668601        0.444134
# 743    0.327675        0.264864
# 744    0.460223        0.569495
# 745    0.438322        0.739441
# 746    0.767667        0.113649
# 747    0.992365        0.480606
#
# [748 rows x 22 columns]

# %%
df_tweets2.to_csv("export_dummy.csv", sep=',', encoding='utf-8')
